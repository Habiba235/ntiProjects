# %% [markdown]
# # Import Libiries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# To ignor the occurance of warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_csv('Customers_Fakedata.csv')

# %%
df
# Out:
#      CustomerID           Name    Age  Gender                      Email  \
# 0      CUST1000     Ali Hassan   72.0     NaN       ali.hassan@gmail.com
# 1      CUST1001      Fatma Ali    NaN  Female      fatma.ali@hotmail.com
# 2      CUST1002  Ahmed Mahmoud   -1.0    male  ahmed.mahmoud@hotmail.com
# 3      CUST1003    Ahmed Gaber   -1.0       F      ahmed.gaber@gmail.com
# 4      CUST1004    Ali Ibrahim   73.0       M      ali.ibrahim@yahoo.com
# ...         ...            ...    ...     ...                        ...
# 2145   CUST1447   Mark Mahmoud   66.0    male   mark.mahmoud@hotmail.com
# 2146   CUST1381   Fatma Hassan    NaN       M     fatma.hassan@yahoo.com
# 2147   CUST2338      Ali Gaber   -1.0       M        ali.gaber@gmail.com
# 2148   CUST1694       John Ali  200.0  Female         john.ali@yahoo.com
# 2149   CUST1567   Ahmed Hassan    NaN    male     ahmed.hassan@yahoo.com
#
#             Phone  PurchaseAmount PurchaseDate ProductCategory  Rating  \
# 0     123456789.0          837.31   2023-10-12           Books     3.0
# 1             NaN          900.25   2023-02-23             NaN     3.0
# 2             NaN          761.72   2023-07-07            Toys     2.0
# 3             NaN          303.72   2023-12-30             NaN     2.0
# 4     987654321.0          635.81   2023-12-07        Clothing     2.0
# ...           ...             ...          ...             ...     ...
# 2145  987654321.0          462.47   2023-08-04            Toys     5.0
# 2146          NaN          237.62   2024-01-28            Toys     5.0
# 2147          NaN          174.72   2024-09-29           Books     NaN
# 2148  987654321.0          250.47   2024-02-05             NaN     5.0
# 2149  123456789.0          891.41   2023-10-13        Clothing     3.0
#
#       Unnamed   Gender
# 0         NaN        NaN
# 1         NaN     Female
# 2         NaN       male
# 3         NaN          F
# 4         NaN          M
# ...       ...        ...
# 2145      NaN       male
# 2146      NaN          M
# 2147      NaN          M
# 2148      NaN     Female
# 2149      NaN       male
#
# [2150 rows x 12 columns]

# %%
# Get more info about data

# %%
df.head(30)
# Out:
#    CustomerID           Name    Age  Gender                      Email  \
# 0    CUST1000     Ali Hassan   72.0     NaN       ali.hassan@gmail.com
# 1    CUST1001      Fatma Ali    NaN  Female      fatma.ali@hotmail.com
# 2    CUST1002  Ahmed Mahmoud   -1.0    male  ahmed.mahmoud@hotmail.com
# 3    CUST1003    Ahmed Gaber   -1.0       F      ahmed.gaber@gmail.com
# 4    CUST1004    Ali Ibrahim   73.0       M      ali.ibrahim@yahoo.com
# 5    CUST1005   Alaa Ibrahim    NaN       F   alaa.ibrahim@hotmail.com
# 6    CUST1006       Mark Ali   -1.0    male       mark.ali@hotmail.com
# 7    CUST1007    Alaa Hassan  200.0  female    alaa.hassan@hotmail.com
# 8    CUST1008    John Hassan   89.0    Male      john.hassan@yahoo.com
# 9    CUST1009    Fatma Gaber  200.0  Female    fatma.gaber@hotmail.com
# 10   CUST1010    Ahmed Smith   -1.0       M      ahmed.smith@gmail.com
# 11   CUST1011     Sara Smith   -1.0    Male       sara.smith@yahoo.com
# 12   CUST1012   Lina Ibrahim    NaN     NaN   lina.ibrahim@hotmail.com
# 13   CUST1013     Lina Gaber    NaN    male       lina.gaber@gmail.com
# 14   CUST1014       Alaa Ali    NaN       M         alaa.ali@gmail.com
# 15   CUST1015    Ali Ibrahim   18.0  female    ali.ibrahim@hotmail.com
# 16   CUST1016   Fatma Hassan  200.0  Female     fatma.hassan@gmail.com
# 17   CUST1017   John Mahmoud  200.0       M     john.mahmoud@gmail.com
# 18   CUST1018       Alaa Ali   15.0  Female       alaa.ali@hotmail.com
# 19   CUST1019  Ahmed Ibrahim   -1.0    Male    ahmed.ibrahim@yahoo.com
# 20   CUST1020     Lina Gaber    NaN       M     lina.gaber@hotmail.com
# 21   CUST1021  Fatma Ibrahim    NaN    male    fatma.ibrahim@yahoo.com
# 22   CUST1022  Ahmed Mahmoud   -1.0     NaN    ahmed.mahmoud@gmail.com
# 23   CUST1023   Lina Ibrahim   44.0       M     lina.ibrahim@yahoo.com
# 24   CUST1024    John Hassan  200.0    Male    john.hassan@hotmail.com
# 25   CUST1025  Fatma Mahmoud   -1.0  Female    fatma.mahmoud@yahoo.com
# 26   CUST1026   Sara Mahmoud   -1.0       M   sara.mahmoud@hotmail.com
# 27   CUST1027   Ahmed Hassan    NaN    male   ahmed.hassan@hotmail.com
# 28   CUST1028     Lina Smith   -1.0    Male       lina.smith@gmail.com
# 29   CUST1029   John Mahmoud   67.0       F   john.mahmoud@hotmail.com
#
#           Phone  PurchaseAmount PurchaseDate ProductCategory  Rating  Unnamed  \
# 0   123456789.0          837.31   2023-10-12           Books     3.0      NaN
# 1           NaN          900.25   2023-02-23             NaN     3.0      NaN
# 2           NaN          761.72   2023-07-07            Toys     2.0      NaN
# 3           NaN          303.72   2023-12-30             NaN     2.0      NaN
# 4   987654321.0          635.81   2023-12-07        Clothing     2.0      NaN
# 5   987654321.0          886.26   2025-01-16             NaN     2.0      NaN
# 6           NaN           92.53   2024-06-12           Books     2.0      NaN
# 7   987654321.0          318.43   2024-05-17            Toys    10.0      NaN
# 8           NaN          883.52   32/13/2020            Home     4.0      NaN
# 9           NaN          966.47   2025-01-24     Electronics     2.0      NaN
# 10  987654321.0          882.19   2025-06-24             NaN     3.0      NaN
# 11          NaN          405.79   2024-08-05             NaN    10.0      NaN
# 12          NaN          142.60   2023-05-23            Home     2.0      NaN
# 13          NaN             NaN   2024-02-04     Electronics     2.0      NaN
# 14          NaN          891.80   2023-05-21        Clothing     NaN      NaN
# 15  123456789.0          337.49   2024-06-25            Home     1.0      NaN
# 16  987654321.0          272.08   2024-01-09            Toys     2.0      NaN
# 17          NaN          833.56   2025-02-19             NaN     NaN      NaN
# 18  123456789.0          923.50   2024-01-04            Toys     1.0      NaN
# 19  123456789.0          497.45   32/13/2020             NaN     1.0      NaN
# 20          NaN          667.69   2023-04-27        Clothing     NaN      NaN
# 21  123456789.0          118.22   2024-12-30        Clothing     1.0      NaN
# 22          NaN           22.02   2025-02-22     Electronics     1.0      NaN
# 23  123456789.0          389.24   32/13/2020        Clothing    10.0      NaN
# 24          NaN          125.65   2023-02-27             NaN    10.0      NaN
# 25  987654321.0          334.63   2025-06-18     Electronics     3.0      NaN
# 26  123456789.0          801.36   32/13/2020             NaN    10.0      NaN
# 27          NaN          478.39   2025-03-22             NaN     NaN      NaN
# 28  123456789.0          303.65   2023-11-10        Clothing     2.0      NaN
# 29          NaN          387.63   2024-02-28           Books     4.0      NaN
#
#      Gender
# 0         NaN
# 1      Female
# 2        male
# 3           F
# 4           M
# 5           F
# 6        male
# 7      female
# 8        Male
# 9      Female
# 10          M
# 11       Male
# 12        NaN
# 13       male
# 14          M
# 15     female
# 16     Female
# 17          M
# 18     Female
# 19       Male
# 20          M
# 21       male
# 22        NaN
# 23          M
# 24       Male
# 25     Female
# 26          M
# 27       male
# 28       Male
# 29          F

# %%
df.tail()
# Out:
#      CustomerID          Name    Age  Gender                     Email  \
# 2145   CUST1447  Mark Mahmoud   66.0    male  mark.mahmoud@hotmail.com
# 2146   CUST1381  Fatma Hassan    NaN       M    fatma.hassan@yahoo.com
# 2147   CUST2338     Ali Gaber   -1.0       M       ali.gaber@gmail.com
# 2148   CUST1694      John Ali  200.0  Female        john.ali@yahoo.com
# 2149   CUST1567  Ahmed Hassan    NaN    male    ahmed.hassan@yahoo.com
#
#             Phone  PurchaseAmount PurchaseDate ProductCategory  Rating  \
# 2145  987654321.0          462.47   2023-08-04            Toys     5.0
# 2146          NaN          237.62   2024-01-28            Toys     5.0
# 2147          NaN          174.72   2024-09-29           Books     NaN
# 2148  987654321.0          250.47   2024-02-05             NaN     5.0
# 2149  123456789.0          891.41   2023-10-13        Clothing     3.0
#
#       Unnamed   Gender
# 2145      NaN       male
# 2146      NaN          M
# 2147      NaN          M
# 2148      NaN     Female
# 2149      NaN       male

# %%
df.sample(5)
# Out:
#      CustomerID         Name   Age  Gender                  Email  \
# 299    CUST1299   John Smith  -1.0     NaN   john.smith@gmail.com
# 565    CUST1565   Lina Smith  -1.0    Male   lina.smith@yahoo.com
# 794    CUST1794  Fatma Smith  -1.0       M  fatma.smith@gmail.com
# 258    CUST1258   Alaa Smith  -1.0    Male   alaa.smith@gmail.com
# 1941   CUST2941  Sara Hassan  85.0  Female  sara.hassan@yahoo.com
#
#             Phone  PurchaseAmount PurchaseDate ProductCategory  Rating  \
# 299   987654321.0          942.66   2023-04-29             NaN     3.0
# 565           NaN          149.73   2023-02-01            Toys     2.0
# 794           NaN           13.48   2025-07-08        Clothing     4.0
# 258           NaN           44.27   2025-04-22     Electronics     2.0
# 1941  987654321.0          761.52   2023-06-01             NaN    10.0
#
#       Unnamed   Gender
# 299       NaN        NaN
# 565       NaN       Male
# 794       NaN          M
# 258       NaN       Male
# 1941      NaN     Female

# %%
df.shape
# Out:
# (2150, 12)

# %%
df.columns
# Out:
# Index(['CustomerID', 'Name', 'Age', 'Gender', 'Email', 'Phone',
#        'PurchaseAmount', 'PurchaseDate', 'ProductCategory', 'Rating',
#        'Unnamed', '  Gender  '],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2150 entries, 0 to 2149
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerID       2150 non-null   object
#  1   Name             2150 non-null   object
#  2   Age              1630 non-null   float64
#  3   Gender           1877 non-null   object
#  4   Email            2150 non-null   object
#  5   Phone            1072 non-null   float64
#  6   PurchaseAmount   2049 non-null   float64
#  7   PurchaseDate     2150 non-null   object
#  8   ProductCategory  1573 non-null   object
#  9   Rating           1821 non-null   float64
#  10  Unnamed          0 non-null      float64
#  11    Gender         1877 non-null   object
# dtypes: float64(5), object(7)
# memory usage: 201.7+ KB

# %%
# Check Missing Values
df.isnull().sum()
# Out:
# CustomerID            0
# Name                  0
# Age                 520
# Gender              273
# Email                 0
# Phone              1078
# PurchaseAmount      101
# PurchaseDate          0
# ProductCategory     577
# Rating              329
# Unnamed            2150
#   Gender            273
# dtype: int64

# %%
# Check Duplicates 
df.duplicated().sum()
# Out:
# 50

# %%
''' Columns to be cleaned 
Age : has 520 missing value
Gender : has 273 missing value  , Not  this repeated      
Phone  : has 1078 missing value  ,   Should change DT to object DT    
PurchaseDate : Should change DT to Date DT
Unnamed : Drop this Column
  Gender    : has 273 missing value  , Not  this repeated 
ProductCategory : has 577 missing value   
Rating : has 329 missing value 
PurchaseAmount : has 101 missing value           
'''
# Out:
# ' Columns to be cleaned \nAge : has 520 missing value\nGender : has 273 missing value  , Not  this repeated      \nPhone  : has 1078 missing value  ,   Should change DT to object DT          \nPurchaseAmount : has 1078 missing value \nPurchaseDate : Should change DT to Date DT\nProductCategory : has 577 missing value    \nRating : has 329 missing value               \nUnnamed : Drop this Column\n  Gender    : has 273 missing value  , Not  this repeated  \n'

# %% [markdown]
# # Data Cleaning

# %%
#  Solve fault Dt
df['Phone'] = df['Phone'].astype('object')

# %%
df['PurchaseDate'].replace({'32/13/2020':'2020-12-30'},inplace=True)
df['PurchaseDate'] = pd.to_datetime(df['PurchaseDate'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2150 entries, 0 to 2149
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerID       2150 non-null   object
#  1   Name             2150 non-null   object
#  2   Age              1630 non-null   float64
#  3   Gender           1877 non-null   object
#  4   Email            2150 non-null   object
#  5   Phone            1072 non-null   object
#  6   PurchaseAmount   2049 non-null   float64
#  7   PurchaseDate     2150 non-null   datetime64[ns]
#  8   ProductCategory  1573 non-null   object
#  9   Rating           1821 non-null   float64
#  10  Unnamed          0 non-null      float64
#  11    Gender         1877 non-null   object
# dtypes: datetime64[ns](1), float64(4), object(7)
# memory usage: 201.7+ KB

# %%
df['PurchaseDate'].isnull().sum()
# Out:
# 0

# %%
df['PurchaseDate'].describe()
# Out:
# count                    2150
# unique                    860
# top       2020-12-30 00:00:00
# freq                      122
# first     2020-12-30 00:00:00
# last      2025-07-23 00:00:00
# Name: PurchaseDate, dtype: object

# %%
# Drop Cloumns
df.drop(columns= ['Unnamed','  Gender  '],inplace=True)

# %%
df.head()
# Out:
#   CustomerID           Name   Age  Gender                      Email  \
# 0   CUST1000     Ali Hassan  72.0     NaN       ali.hassan@gmail.com
# 1   CUST1001      Fatma Ali   NaN  Female      fatma.ali@hotmail.com
# 2   CUST1002  Ahmed Mahmoud  -1.0    male  ahmed.mahmoud@hotmail.com
# 3   CUST1003    Ahmed Gaber  -1.0       F      ahmed.gaber@gmail.com
# 4   CUST1004    Ali Ibrahim  73.0       M      ali.ibrahim@yahoo.com
#
#          Phone  PurchaseAmount PurchaseDate ProductCategory  Rating
# 0  123456789.0          837.31   2023-10-12           Books     3.0
# 1          NaN          900.25   2023-02-23             NaN     3.0
# 2          NaN          761.72   2023-07-07            Toys     2.0
# 3          NaN          303.72   2023-12-30             NaN     2.0
# 4  987654321.0          635.81   2023-12-07        Clothing     2.0

# %%
df.columns
# Out:
# Index(['CustomerID', 'Name', 'Age', 'Gender', 'Email', 'Phone',
#        'PurchaseAmount', 'PurchaseDate', 'ProductCategory', 'Rating'],
#       dtype='object')

# %%
# Solve Duplication problem
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (2100, 10)

# %%
# Handel Phone Column
df['Phone'].unique()
# Out:
# array([123456789.0, nan, 987654321.0], dtype=object)

# %%
df['Phone'].value_counts()
# Out:
# 987654321.0    534
# 123456789.0    509
# Name: Phone, dtype: int64

# %%
df.drop(columns='Phone',inplace = True)

# %%
df.head()
# Out:
#   CustomerID           Name   Age  Gender                      Email  \
# 0   CUST1000     Ali Hassan  72.0     NaN       ali.hassan@gmail.com
# 1   CUST1001      Fatma Ali   NaN  Female      fatma.ali@hotmail.com
# 2   CUST1002  Ahmed Mahmoud  -1.0    male  ahmed.mahmoud@hotmail.com
# 3   CUST1003    Ahmed Gaber  -1.0       F      ahmed.gaber@gmail.com
# 4   CUST1004    Ali Ibrahim  73.0       M      ali.ibrahim@yahoo.com
#
#    PurchaseAmount PurchaseDate ProductCategory  Rating
# 0          837.31   2023-10-12           Books     3.0
# 1          900.25   2023-02-23             NaN     3.0
# 2          761.72   2023-07-07            Toys     2.0
# 3          303.72   2023-12-30             NaN     2.0
# 4          635.81   2023-12-07        Clothing     2.0

# %%
# Handel Gender Column
df['Gender'].nunique()
# Out:
# 6

# %%
df['Gender'].unique()
# Out:
# array([nan, 'Female', 'male', 'F', 'M', 'female', 'Male'], dtype=object)

# %%
df['Gender'].value_counts()
# Out:
# M         335
# Female    309
# Male      309
# male      298
# F         293
# female    289
# Name: Gender, dtype: int64

# %%
df['Gender'] = df['Gender'].str.lower()

# %%
df['Gender'].value_counts()
# Out:
# male      607
# female    598
# m         335
# f         293
# Name: Gender, dtype: int64

# %%
df['Gender'].replace({'m':'male','f':'female'},inplace=True)

# %%
df['Gender'].unique()
# Out:
# array([nan, 'female', 'male'], dtype=object)

# %%
df['Gender'].value_counts()
# Out:
# male      942
# female    891
# Name: Gender, dtype: int64

# %%
df.describe(include='O').T
# Out:
#                 count unique                    top freq
# CustomerID       2100   2100               CUST1000    1
# Name             2100     48            Sara Hassan   58
# Gender           1833      2                   male  942
# Email            2100    144  sara.hassan@yahoo.com   26
# ProductCategory  1535      5               Clothing  323

# %%
df['Gender'].fillna('male',inplace=True)

# %%
df['Gender'].value_counts()
# Out:
# male      1209
# female     891
# Name: Gender, dtype: int64

# %%
df['Gender'].isnull().sum()
# Out:
# 0

# %%
# Handel Age Column
df['Age'].unique()
# Out:
# array([ 72.,  nan,  -1.,  73., 200.,  89.,  18.,  15.,  44.,  67.,  62.,
#         90.,  70.,  46.,  57.,  81.,  29.,  83.,  41.,  31.,  40.,  79.,
#         35.,  53.,  87.,  30.,  23.,  84.,  26.,  36.,  33.,  58.,  49.,
#         28.,  65.,  71.,  56.,  76.,  25.,  43.,  21.,  63.,  66.,  77.,
#         16.,  82.,  22.,  34.,  50.,  19.,  48.,  52.,  80.,  27.,  69.,
#         60.,  88.,  78.,  85.,  64.,  45.,  38.,  54.,  74.,  39.,  32.,
#         37.,  68.,  17.,  47.,  42.,  61.,  51.,  24.,  55.,  86.,  75.,
#         20.,  59.])

# %%
df['Age'].min()
# Out:
# -1.0

# %%
df['Age'].max()
# Out:
# 200.0

# %%
sns.histplot(df,x='Age')
plt.show()

# %%
# Handel Outliers
df['Age'].replace({200.:20,-1.:15.},inplace=True)

# %%
df['Age'].min()
# Out:
# 15.0

# %%
df['Age'].max()
# Out:
# 90.0

# %%
df['Age'].describe()
# Out:
# count    1594.000000
# mean       28.939147
# std        20.985618
# min        15.000000
# 25%        15.000000
# 50%        20.000000
# 75%        32.000000
# max        90.000000
# Name: Age, dtype: float64

# %%
sns.histplot(df,x='Age',kde=True)
plt.show()

# %%
df['Age'].fillna(df['Age'].median(),inplace=True)

# %%
df['Age'].isnull().sum()
# Out:
# 0

# %%
df['Age'].describe()
# Out:
# count    2100.000000
# mean       26.785238
# std        18.677603
# min        15.000000
# 25%        15.000000
# 50%        20.000000
# 75%        20.000000
# max        90.000000
# Name: Age, dtype: float64

# %%
sns.histplot(df,x='Age',kde=True)
plt.show()

# %%
# Handel Product Category Column
df['ProductCategory'].unique()
# Out:
# array(['Books', nan, 'Toys', 'Clothing', 'Home', 'Electronics'],
#       dtype=object)

# %%
df['ProductCategory'].value_counts()
# Out:
# Clothing       323
# Electronics    323
# Books          305
# Home           296
# Toys           288
# Name: ProductCategory, dtype: int64

# %%
df['ProductCategory'].isnull().sum()
# Out:
# 565

# %%
df['ProductCategory'].fillna('Other',inplace=True)

# %%
df['ProductCategory'].value_counts()
# Out:
# Other          565
# Clothing       323
# Electronics    323
# Books          305
# Home           296
# Toys           288
# Name: ProductCategory, dtype: int64

# %%
# Handel Rating Column 
df['Rating'].unique()
# Out:
# array([ 3.,  2., 10.,  4., nan,  1.,  5.])

# %%
df['Rating'].value_counts()
# Out:
# 3.0     326
# 2.0     310
# 5.0     307
# 10.0    291
# 4.0     278
# 1.0     266
# Name: Rating, dtype: int64

# %%
df['Rating'].replace({10.0:5.0},inplace=True)

# %%
df['Rating'].fillna(3.0,inplace=True)

# %%
df['Rating'].unique()
# Out:
# array([3., 2., 5., 4., 1.])

# %%
# Handel Purchase Amount Column
df['PurchaseAmount'].describe()
# Out:
# count    2003.000000
# mean      509.897379
# std       288.493923
# min         5.060000
# 25%       263.495000
# 50%       519.420000
# 75%       765.180000
# max       999.560000
# Name: PurchaseAmount, dtype: float64

# %%
sns.histplot(df,x='PurchaseAmount',kde=True)
plt.show()

# %%
df['PurchaseAmount'].fillna(df['PurchaseAmount'].mean(),inplace=True)

# %%
df['PurchaseAmount'].isnull().sum()
# Out:
# 0

# %%
sns.histplot(df,x='PurchaseAmount',kde=True)
plt.show()

# %%
# Check Cleaning 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2100 entries, 0 to 2099
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerID       2100 non-null   object
#  1   Name             2100 non-null   object
#  2   Age              2100 non-null   float64
#  3   Gender           2100 non-null   object
#  4   Email            2100 non-null   object
#  5   PurchaseAmount   2100 non-null   float64
#  6   PurchaseDate     2100 non-null   datetime64[ns]
#  7   ProductCategory  2100 non-null   object
#  8   Rating           2100 non-null   float64
# dtypes: datetime64[ns](1), float64(3), object(5)
# memory usage: 228.6+ KB

# %%
df.isnull().sum()
# Out:
# CustomerID         0
# Name               0
# Age                0
# Gender             0
# Email              0
# PurchaseAmount     0
# PurchaseDate       0
# ProductCategory    0
# Rating             0
# dtype: int64

# %%
df.head(10)
# Out:
#   CustomerID           Name   Age  Gender                      Email  \
# 0   CUST1000     Ali Hassan  72.0    male       ali.hassan@gmail.com
# 1   CUST1001      Fatma Ali  20.0  female      fatma.ali@hotmail.com
# 2   CUST1002  Ahmed Mahmoud  15.0    male  ahmed.mahmoud@hotmail.com
# 3   CUST1003    Ahmed Gaber  15.0  female      ahmed.gaber@gmail.com
# 4   CUST1004    Ali Ibrahim  73.0    male      ali.ibrahim@yahoo.com
# 5   CUST1005   Alaa Ibrahim  20.0  female   alaa.ibrahim@hotmail.com
# 6   CUST1006       Mark Ali  15.0    male       mark.ali@hotmail.com
# 7   CUST1007    Alaa Hassan  20.0  female    alaa.hassan@hotmail.com
# 8   CUST1008    John Hassan  89.0    male      john.hassan@yahoo.com
# 9   CUST1009    Fatma Gaber  20.0  female    fatma.gaber@hotmail.com
#
#    PurchaseAmount PurchaseDate ProductCategory  Rating
# 0          837.31   2023-10-12           Books     3.0
# 1          900.25   2023-02-23           Other     3.0
# 2          761.72   2023-07-07            Toys     2.0
# 3          303.72   2023-12-30           Other     2.0
# 4          635.81   2023-12-07        Clothing     2.0
# 5          886.26   2025-01-16           Other     2.0
# 6           92.53   2024-06-12           Books     2.0
# 7          318.43   2024-05-17            Toys     5.0
# 8          883.52   2020-12-30            Home     4.0
# 9          966.47   2025-01-24     Electronics     2.0

# %%
# To Save Data in new CSV file
df.to_csv('Customers_Fakedata_Cleaned')

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
# Top 10 PurchaseAmount
df.sort_values(by= 'PurchaseAmount',ascending=False).head(10)
# Out:
#      CustomerID           Name   Age  Gender                    Email  \
# 687    CUST1687   Alaa Ibrahim  20.0  female   alaa.ibrahim@yahoo.com
# 1949   CUST2949  Fatma Mahmoud  63.0  female  fatma.mahmoud@yahoo.com
# 424    CUST1424       John Ali  80.0    male       john.ali@gmail.com
# 1832   CUST2832       John Ali  49.0    male       john.ali@yahoo.com
# 1961   CUST2961   Mark Mahmoud  15.0    male   mark.mahmoud@yahoo.com
# 631    CUST1631   Lina Mahmoud  18.0  female   lina.mahmoud@gmail.com
# 386    CUST1386      Fatma Ali  20.0  female    fatma.ali@hotmail.com
# 335    CUST1335   Alaa Mahmoud  15.0  female   alaa.mahmoud@yahoo.com
# 908    CUST1908       Sara Ali  20.0  female       sara.ali@yahoo.com
# 1708   CUST2708    Sara Hassan  15.0  female    sara.hassan@yahoo.com
#
#       PurchaseAmount PurchaseDate ProductCategory  Rating
# 687           999.56   2025-05-16     Electronics     1.0
# 1949          999.30   2024-04-10        Clothing     3.0
# 424           999.23   2024-06-30            Toys     5.0
# 1832          999.00   2024-10-10            Toys     1.0
# 1961          998.59   2025-04-25     Electronics     2.0
# 631           998.16   2023-10-09           Books     5.0
# 386           995.55   2022-11-12        Clothing     4.0
# 335           995.41   2024-02-11            Toys     3.0
# 908           995.32   2023-09-04        Clothing     1.0
# 1708          995.25   2023-05-17     Electronics     3.0

# %%
# Top Sold Product Category 
df['ProductCategory'].value_counts()
# Out:
# Other          565
# Clothing       323
# Electronics    323
# Books          305
# Home           296
# Toys           288
# Name: ProductCategory, dtype: int64

# %%
# Total Slaes 
df['PurchaseAmount'].sum()
# Out:
# 1070784.4957563654

# %%
round(df['PurchaseAmount'].sum(),1)
# Out:
# 1070784.5

# %%
# Total Slaes 
total = round(df['PurchaseAmount'].sum(),1)
formatt = f"${total:,.1f}"
print(formatt)
# Out:
# $1,070,784.5

# %%
# Avg Sales 
Avg = round(df['PurchaseAmount'].mean(),1)
formatt = f"${Avg}"
print(formatt)
# Out:
# $509.9

# %%
# What is the most Customer gender segment 
Gender_Count = df['Gender'].value_counts()
Gender_Count
# Out:
# male      1209
# female     891
# Name: Gender, dtype: int64

# %%
sns.countplot(df,x="Gender",label=Gender_Count)
plt.show()

# %%
count = [1209,891]
label = ['male','female']
plt.figure(figsize=(9,7))
plt.pie(count,labels=label,autopct='%1.1f%%')
plt.show()

# %%
plt.figure(figsize=(9,7))
plt.pie(Gender_Count,labels=Gender_Count.index,autopct='%1.1f%%')
plt.show()

# %%
sns.barplot(df,x='Gender',y='PurchaseAmount')
plt.show()

# %%
# What is the month we in generates most Sales
# Out:
# Index(['CustomerID', 'Name', 'Age', 'Gender', 'Email', 'PurchaseAmount',
#        'PurchaseDate', 'ProductCategory', 'Rating'],
#       dtype='object')

# %%
df['Month'] = df['PurchaseDate'].dt.month

# %%
df
# Out:
#      CustomerID           Name   Age  Gender                      Email  \
# 0      CUST1000     Ali Hassan  72.0    male       ali.hassan@gmail.com
# 1      CUST1001      Fatma Ali  20.0  female      fatma.ali@hotmail.com
# 2      CUST1002  Ahmed Mahmoud  15.0    male  ahmed.mahmoud@hotmail.com
# 3      CUST1003    Ahmed Gaber  15.0  female      ahmed.gaber@gmail.com
# 4      CUST1004    Ali Ibrahim  73.0    male      ali.ibrahim@yahoo.com
# ...         ...            ...   ...     ...                        ...
# 2095   CUST3095       Alaa Ali  36.0    male       alaa.ali@hotmail.com
# 2096   CUST3096     Lina Gaber  20.0  female       lina.gaber@yahoo.com
# 2097   CUST3097    Ali Ibrahim  20.0  female    ali.ibrahim@hotmail.com
# 2098   CUST3098   Mark Mahmoud  20.0  female   mark.mahmoud@hotmail.com
# 2099   CUST3099    Lina Hassan  20.0    male      lina.hassan@gmail.com
#
#       PurchaseAmount PurchaseDate ProductCategory  Rating  Month
# 0             837.31   2023-10-12           Books     3.0     10
# 1             900.25   2023-02-23           Other     3.0      2
# 2             761.72   2023-07-07            Toys     2.0      7
# 3             303.72   2023-12-30           Other     2.0     12
# 4             635.81   2023-12-07        Clothing     2.0     12
# ...              ...          ...             ...     ...    ...
# 2095          708.91   2025-06-06           Other     4.0      6
# 2096           70.47   2023-08-06            Toys     4.0      8
# 2097          804.19   2023-11-02        Clothing     4.0     11
# 2098          328.31   2023-03-24           Other     1.0      3
# 2099          253.78   2023-01-18           Books     3.0      1
#
# [2100 rows x 10 columns]

# %%
df['Month'].nunique()
# Out:
# 12

# %%
round(df.groupby('Month')['PurchaseAmount'].sum(),2)
# Out:
# Month
# 1      80632.26
# 2      79530.30
# 3      91837.46
# 4      88399.40
# 5     101312.70
# 6      99607.76
# 7      74980.74
# 8      61325.82
# 9      59303.40
# 10     73268.84
# 11     98832.04
# 12    161753.78
# Name: PurchaseAmount, dtype: float64

# %%
round(df.groupby('Month')['PurchaseAmount'].sum(),2).sort_values(ascending =False)
# Out:
# Month
# 12    161753.78
# 5     101312.70
# 6      99607.76
# 11     98832.04
# 3      91837.46
# 4      88399.40
# 1      80632.26
# 2      79530.30
# 7      74980.74
# 10     73268.84
# 8      61325.82
# 9      59303.40
# Name: PurchaseAmount, dtype: float64

# %%
round(df.groupby('Month')['PurchaseAmount'].sum(),2).sort_index().plot(figsize=(15,5),linestyle='--',linewidth=4)
plt.ylabel('Purchase Amount')
plt.xlabel('Month')
plt.title('Monthly Sales',fontsize=24)
plt.show()
